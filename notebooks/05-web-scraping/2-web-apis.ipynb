# %% [markdown]
# <img src="images/banner.png" style="width: 100%;">

# %% [markdown]
# # Using Web APIs with Python

# %%
# conda install python-dotenv -y # we need to install python-dotenv to read .env files then set them as environment variables

# %% [markdown]
# References:
#
# [1] Mitchell, Ryan. *Web scraping with python.* " O'Reilly Media, Inc.", 2024.
#
# [2] Chapagain, Anish. *Hands-On Web Scraping with Python: Extract quality data from the web using effective Python techniques.* Packt Publishing Ltd, 2023.
#
# [3] Elridge, Taryn. *Web automation and scraping with Python: Hands-on mastery of selenium, beautifulsoup, and real-world data extraction.* 2025.
#
# [4] Requests Documentation - https://requests.readthedocs.io/en/latest/user/quickstart/
#
# [5] Revised and grammar checked using ChatGPT - https://chatgpt.com/

# %% [markdown]
# Prepared by: Leodegario Lorenzo II

# %% [markdown]
# In this notebook, we will demonstrate how to use and integrate APIs into our code. Specifically, we will use the `requests` library to send HTTP requests to several APIs, retrieve their responses, and process the returned data for further use.
#
# In essence, an **Application Programming Interface (API)** is a standardized interface that allows one software application to communicate with another. APIs enable systems to exchange data and functionality, even if they are built using different programming languages or architectures.
#
# In particular, we will focus on **Web APIs**, which allow us to access data from remote servers over the internet. These APIs are commonly used to retrieve structured data that can then be analyzed, transformed, or stored within our own applications.

# %% [markdown]
# We will cover:
#
# 1. **API prerequisites** — including understanding documentation and securing access credentials (e.g., API keys).
#
# 2. **Sending API requests** using the requests library.
#
# 3. **Processing API responses** — parsing the returned data (typically `JSON`) and storing it for further analysis.

# %%
import json
from time import sleep

import requests
import pandas as pd

# %% [markdown]
# ## 1 IP Geolocation

# %% [markdown]
# The first API that we will use in this notebook is the **[IP Geolocation API](https://ip-api.com/)** which is a free for non-commercial use, no key required API, that translates an input IP address to a physical address. The documentation for this API can be found at:
#
# https://ip-api.com/docs
#
# Specifically we will use the `JSON` endpoint for this API.
#
# ```
# http://ip-api.com/json/{query}
# ```
#
# With optional parameters
#
# | Parameter | Description |
# | :--- | :--- |
# | **fields** | response fields *optional* |
# | **lang** | response language *optional* |
# | **callback** | wrap inside (JSONP) *optional* |
#
# We also note that the *Usage limit* for this API is **45 requests per minute** from an IP address.

# %% [markdown]
# Let's demonstrate how we perform calls to this API using request. First, we form the path according to our desired query. For this example, let's say we want to find the address of a friend with an IP address of `61.9.109.182`.

# %%
query = '61.9.109.182'
base_url = f'http://ip-api.com/json/{query}'

response = requests.get(base_url)
response
# Out:
# <Response [200]>

# %% [markdown]
# If the request was successfull and the response is OK (`200`), we can digest the result using the `.json()` method of the `Response` object.

# %%
response.json()
# Out:
# {'status': 'success',
#  'country': 'Philippines',
#  'countryCode': 'PH',
#  'region': '00',
#  'regionName': 'Metro Manila',
#  'city': 'Quezon City',
#  'zip': '1114',
#  'lat': 14.6538,
#  'lon': 121.0634,
#  'timezone': 'Asia/Manila',
#  'isp': 'Sky Cable Corporation',
#  'org': 'Sky Cable Corporation',
#  'as': 'AS17970 SKYBroadband SKYCable Corporation',
#  'query': '61.9.109.182'}

# %% [markdown]
# Let's say we want to integrate this API with a program that calculates the distance between the address of a given ip address with a particular location. Firstly, we might want to limit the output to only include the `status`, `message` (if the request fails), and the `lat` and `lon` coordinates.

# %%
def get_lat_lon(ip_address):
    base_url = f'http://ip-api.com/json/{ip_address}'
    params = {'fields': 'status,message,lat,lon'}

    try:
        response = requests.get(base_url, params=params)
        data = response.json()
        response.raise_for_status()
        if data['status'] == 'fail':
            raise requests.RequestException(data['message'])
    except requests.RequestException as e:
        print("Failed request: ", e)
        return None, None
    else:
        return data['lat'], data['lon']

# %%
from utils import haversine

# %%
# Known location - Kilometer 0 (Rizal Park)
lat = 14.5826446
lon = 120.9761138

# Get lat and lon coordinates of input IP address
ip_address = '61.9.109.182'
ip_lat, ip_lon = get_lat_lon(ip_address)

# Calculate the distance between the two points
distance = haversine(lat, lon, ip_lat, ip_lon)

print(f"The distance of the query to Rizal park is {distance:.2f} km.")
# Out:
# The distance of the query to Rizal park is 12.28 km.

# %% [markdown]
# ## 2 OpenWeather

# %% [markdown]
# The next API that we'll be using is the **OpenWeatherMap** API. Which can be used to fetch historical weather data for a given coordinates. It requires a free API key from https://openweathermap.org/
#
# To use this API,
#
# 1. **Get an API Key**: Sign up at [OpenWeatherMap](https://openweathermap.org/) to get your API key. Verify your email address.
# 2. **Add your API Key to the environment variables**: Place your API Key onto an `.env` file using the environment variable `OPENWEATHER_API_KEY`.
# 3. **Check the documentation**: The documentation of the API that we'll be using can be found at [OpenWeather Curent Forecast API Docs](https://openweathermap.org/current?collection=current_forecast)
# 4. **Check the rate limits**: For a free plan, the rate limit is `60` calls per minute and `1,000,000` calls per month.  See [Subscriptions](https://home.openweathermap.org/subscriptions) and [Pricing](https://openweathermap.org/price) for more details.

# %% [markdown]
# To load our environment variables, we use the `dotenv` library.

# %%
import os

from dotenv import load_dotenv


# Load environment variables in the `.env` file found in this folder
load_dotenv();

# %% [markdown]
# ### Geocoding API

# %% [markdown]
# Say we want to use the **OpenWeather API** to get the current weather for the city of `Makati`. We need to first get the `lat` and `lon` of the city since this is the required parameter in the **Current Forecast API**. To do this, OpenWeatherMap provides a simple **Geocoding API** which we can use.

# %%
city_name = 'Makati City'
limit = 1
api_key = os.getenv('OPENWEATHER_API_KEY')

endpoint = 'http://api.openweathermap.org/geo/1.0/direct'
params = {'q': city_name, 'appid': api_key, 'limit': limit}

response = requests.get(endpoint, params=params)
response.status_code
# Out:
# 200

# %% [markdown]
# Let's check the result of our API call:

# %%
result = response.json()
result
# Out:
# [{'name': 'Makati',
#   'local_names': {'ru': 'Макати',
#    'es': 'Macati',
#    'ja': 'マカティ',
#    'ks': 'مکاتی',
#    'tl': 'Makati',
#    'ur': 'مکاتی',
#    'fa': 'ماکاتی',
#    'en': 'Makati',
#    'ar': 'ماكاتي'},
#   'lat': 14.5567949,
#   'lon': 121.0211226,
#   'country': 'PH'}]

# %% [markdown]
# We can then use the result for our succeeding API calls, when we try to determine the weather in the city of Makati.

# %%
lat, lon = result[0]['lat'], result[0]['lon']

# %% [markdown]
# ### Current Weather Data

# %% [markdown]
# Let's now use the **[Current Weather Data API](https://openweathermap.org/current?collection=current_forecast)** to access the current weather data for any given location. As an example, let's use Makati City as the location of interest for our query.

# %%
units = 'metric'

endpoint = 'https://api.openweathermap.org/data/2.5/weather'
params = {'lat': lat, 'lon': lon, 'appid': api_key, 'units': units}

response = requests.get(endpoint, params)
response.status_code
# Out:
# 200

# %%
result = response.json()
result
# Out:
# {'coord': {'lon': 121.0211, 'lat': 14.5568},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 28.65,
#   'feels_like': 31.49,
#   'temp_min': 27.6,
#   'temp_max': 29.86,
#   'pressure': 1011,
#   'humidity': 67,
#   'sea_level': 1011,
#   'grnd_level': 1010},
#  'visibility': 10000,
#  'wind': {'speed': 4.63, 'deg': 130},
#  'clouds': {'all': 20},
#  'dt': 1772536391,
#  'sys': {'type': 1,
#   'id': 8160,
#   'country': 'PH',
#   'sunrise': 1772489518,
#   'sunset': 1772532258},
#  'timezone': 28800,
#  'id': 7091184,
#  'name': 'Valenzuela',
#  'cod': 200}

# %% [markdown]
# ### 5 Day Weather Forecast

# %% [markdown]
# We also demonstrate the use of 5-day with data every 3 hours weather forecast API. See **[5 Day Weather Forecast API](https://openweathermap.org/forecast5?collection=current_forecast)** for documentation.

# %%
units = 'metric'

endpoint = 'https://api.openweathermap.org/data/2.5/forecast'
params = {'lat': lat, 'lon': lon, 'appid': api_key, 'units': units}

response = requests.get(endpoint, params)
response.status_code
# Out:
# 200

# %%
result = response.json()
result
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1772539200,
#    'main': {'temp': 28.49,
#     'feels_like': 31.18,
#     'temp_min': 28.4,
#     'temp_max': 28.49,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 67,
#     'temp_kf': 0.09},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 5.74, 'deg': 139, 'gust': 6.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-03 12:00:00'},
#   {'dt': 1772550000,
#    'main': {'temp': 27.89,
#     'feels_like': 30.33,
#     'temp_min': 26.68,
#     'temp_max': 27.89,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1013,
#     'humidity': 69,
#     'temp_kf': 1.21},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 21},
#    'wind': {'speed': 4.69, 'deg': 101, 'gust': 4.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-03 15:00:00'},
#   {'dt': 1772560800,
#    'main': {'temp': 26.69,
#     'feels_like': 28.48,
#     'temp_min': 25.79,
#     'temp_max': 26.69,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 72,
#     'temp_kf': 0.9},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 3.18, 'deg': 101, 'gust': 3.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-03 18:00:00'},
#   {'dt': 1772571600,
#    'main': {'temp': 24.64,
#     'feels_like': 25.17,
#     'temp_min': 24.64,
#     'temp_max': 24.64,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 3.18, 'deg': 102, 'gust': 3.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-03 21:00:00'},
#   {'dt': 1772582400,
#    'main': {'temp': 25.94,
#     'feels_like': 26.5,
#     'temp_min': 25.94,
#     'temp_max': 25.94,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1013,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 3.21, 'deg': 113, 'gust': 3.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-04 00:00:00'},
#   {'dt': 1772593200,
#    'main': {'temp': 29.08,
#     'feels_like': 30.71,
#     'temp_min': 29.08,
#     'temp_max': 29.08,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 0.74, 'deg': 200, 'gust': 3.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-04 03:00:00'},
#   {'dt': 1772604000,
#    'main': {'temp': 30.83,
#     'feels_like': 33.14,
#     'temp_min': 30.83,
#     'temp_max': 30.83,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1009,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 4.98, 'deg': 167, 'gust': 5.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-04 06:00:00'},
#   {'dt': 1772614800,
#    'main': {'temp': 30.32,
#     'feels_like': 32.63,
#     'temp_min': 30.32,
#     'temp_max': 30.32,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1008,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 7.12, 'deg': 123, 'gust': 8.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-04 09:00:00'},
#   {'dt': 1772625600,
#    'main': {'temp': 26.86,
#     'feels_like': 28.55,
#     'temp_min': 26.86,
#     'temp_max': 26.86,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1011,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 6.79, 'deg': 111, 'gust': 7.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-04 12:00:00'},
#   {'dt': 1772636400,
#    'main': {'temp': 25.86,
#     'feels_like': 26.36,
#     'temp_min': 25.86,
#     'temp_max': 25.86,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.02, 'deg': 98, 'gust': 4.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-04 15:00:00'},
#   {'dt': 1772647200,
#    'main': {'temp': 25.07,
#     'feels_like': 25.56,
#     'temp_min': 25.07,
#     'temp_max': 25.07,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1011,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 3.17, 'deg': 91, 'gust': 3.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-04 18:00:00'},
#   {'dt': 1772658000,
#    'main': {'temp': 25.01,
#     'feels_like': 25.55,
#     'temp_min': 25.01,
#     'temp_max': 25.01,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1011,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 3.32, 'deg': 109, 'gust': 4.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-04 21:00:00'},
#   {'dt': 1772668800,
#    'main': {'temp': 25.89,
#     'feels_like': 26.41,
#     'temp_min': 25.89,
#     'temp_max': 25.89,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 3.4, 'deg': 90, 'gust': 4.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-05 00:00:00'},
#   {'dt': 1772679600,
#    'main': {'temp': 29.16,
#     'feels_like': 31.15,
#     'temp_min': 29.16,
#     'temp_max': 29.16,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 1.69, 'deg': 140, 'gust': 4.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-05 03:00:00'},
#   {'dt': 1772690400,
#    'main': {'temp': 30.14,
#     'feels_like': 32.7,
#     'temp_min': 30.14,
#     'temp_max': 30.14,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1009,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 4.32, 'deg': 127, 'gust': 6.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-05 06:00:00'},
#   {'dt': 1772701200,
#    'main': {'temp': 30.15,
#     'feels_like': 32.33,
#     'temp_min': 30.15,
#     'temp_max': 30.15,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1009,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 5.73, 'deg': 118, 'gust': 6.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-05 09:00:00'},
#   {'dt': 1772712000,
#    'main': {'temp': 27.25,
#     'feels_like': 29.01,
#     'temp_min': 27.25,
#     'temp_max': 27.25,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 6.29, 'deg': 111, 'gust': 7.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-05 12:00:00'},
#   {'dt': 1772722800,
#    'main': {'temp': 26.03,
#     'feels_like': 26.03,
#     'temp_min': 26.03,
#     'temp_max': 26.03,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1012,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 3.56, 'deg': 103, 'gust': 4.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-05 15:00:00'},
#   {'dt': 1772733600,
#    'main': {'temp': 25.21,
#     'feels_like': 25.69,
#     'temp_min': 25.21,
#     'temp_max': 25.21,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 2.48, 'deg': 64, 'gust': 2.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-05 18:00:00'},
#   {'dt': 1772744400,
#    'main': {'temp': 24.7,
#     'feels_like': 25.13,
#     'temp_min': 24.7,
#     'temp_max': 24.7,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1011,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 1.41, 'deg': 72, 'gust': 1.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-05 21:00:00'},
#   {'dt': 1772755200,
#    'main': {'temp': 25.49,
#     'feels_like': 25.97,
#     'temp_min': 25.49,
#     'temp_max': 25.49,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1013,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 2.38, 'deg': 102, 'gust': 2.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-06 00:00:00'},
#   {'dt': 1772766000,
#    'main': {'temp': 29.1,
#     'feels_like': 30.6,
#     'temp_min': 29.1,
#     'temp_max': 29.1,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1012,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 1.23, 'deg': 159, 'gust': 3.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-06 03:00:00'},
#   {'dt': 1772776800,
#    'main': {'temp': 30.66,
#     'feels_like': 32.63,
#     'temp_min': 30.66,
#     'temp_max': 30.66,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1009,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 3.64, 'deg': 153, 'gust': 5.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-06 06:00:00'},
#   {'dt': 1772787600,
#    'main': {'temp': 30.22,
#     'feels_like': 32.65,
#     'temp_min': 30.22,
#     'temp_max': 30.22,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1009,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 5.49, 'deg': 118, 'gust': 7.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-06 09:00:00'},
#   {'dt': 1772798400,
#    'main': {'temp': 27.3,
#     'feels_like': 28.99,
#     'temp_min': 27.3,
#     'temp_max': 27.3,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 6.54, 'deg': 109, 'gust': 7.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-06 12:00:00'},
#   {'dt': 1772809200,
#    'main': {'temp': 26.4,
#     'feels_like': 26.4,
#     'temp_min': 26.4,
#     'temp_max': 26.4,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1013,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4, 'deg': 97, 'gust': 5.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-06 15:00:00'},
#   {'dt': 1772820000,
#    'main': {'temp': 25.59,
#     'feels_like': 26.06,
#     'temp_min': 25.59,
#     'temp_max': 25.59,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 2.63, 'deg': 64, 'gust': 2.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-06 18:00:00'},
#   {'dt': 1772830800,
#    'main': {'temp': 24.99,
#     'feels_like': 25.48,
#     'temp_min': 24.99,
#     'temp_max': 24.99,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 2.3, 'deg': 87, 'gust': 2.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-06 21:00:00'},
#   {'dt': 1772841600,
#    'main': {'temp': 25.78,
#     'feels_like': 26.24,
#     'temp_min': 25.78,
#     'temp_max': 25.78,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1013,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 1.71, 'deg': 63, 'gust': 2.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-07 00:00:00'},
#   {'dt': 1772852400,
#    'main': {'temp': 29.32,
#     'feels_like': 30.94,
#     'temp_min': 29.32,
#     'temp_max': 29.32,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1012,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 1.58, 'deg': 118, 'gust': 3.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-07 03:00:00'},
#   {'dt': 1772863200,
#    'main': {'temp': 30.77,
#     'feels_like': 32.82,
#     'temp_min': 30.77,
#     'temp_max': 30.77,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1010,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 4.75, 'deg': 80, 'gust': 5.66},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-07 06:00:00'},
#   {'dt': 1772874000,
#    'main': {'temp': 29.79,
#     'feels_like': 31.37,
#     'temp_min': 29.79,
#     'temp_max': 29.79,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1010,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 6.58, 'deg': 83, 'gust': 7.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-07 09:00:00'},
#   {'dt': 1772884800,
#    'main': {'temp': 27.5,
#     'feels_like': 29.21,
#     'temp_min': 27.5,
#     'temp_max': 27.5,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 5.29, 'deg': 96, 'gust': 7.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-07 12:00:00'},
#   {'dt': 1772895600,
#    'main': {'temp': 26.88,
#     'feels_like': 28.5,
#     'temp_min': 26.88,
#     'temp_max': 26.88,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1013,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.04, 'deg': 89, 'gust': 6.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-07 15:00:00'},
#   {'dt': 1772906400,
#    'main': {'temp': 26.46,
#     'feels_like': 26.46,
#     'temp_min': 26.46,
#     'temp_max': 26.46,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 3.94, 'deg': 83, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-07 18:00:00'},
#   {'dt': 1772917200,
#    'main': {'temp': 26,
#     'feels_like': 26,
#     'temp_min': 26,
#     'temp_max': 26,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1012,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 3.39, 'deg': 71, 'gust': 5.93},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.1},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-03-07 21:00:00'},
#   {'dt': 1772928000,
#    'main': {'temp': 27.11,
#     'feels_like': 28.54,
#     'temp_min': 27.11,
#     'temp_max': 27.11,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1013,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 4.89, 'deg': 70, 'gust': 8.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-08 00:00:00'},
#   {'dt': 1772938800,
#    'main': {'temp': 29.49,
#     'feels_like': 31.06,
#     'temp_min': 29.49,
#     'temp_max': 29.49,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1013,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 5.73, 'deg': 63, 'gust': 7.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-08 03:00:00'},
#   {'dt': 1772949600,
#    'main': {'temp': 30.36,
#     'feels_like': 31.77,
#     'temp_min': 30.36,
#     'temp_max': 30.36,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1010,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 6.15, 'deg': 61, 'gust': 7.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-08 06:00:00'},
#   {'dt': 1772960400,
#    'main': {'temp': 28.72,
#     'feels_like': 30.16,
#     'temp_min': 28.72,
#     'temp_max': 28.72,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1011,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 46},
#    'wind': {'speed': 5.81, 'deg': 65, 'gust': 6.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-03-08 09:00:00'}],
#  'city': {'id': 1703417,
#   'name': 'Makati City',
#   'coord': {'lat': 14.5568, 'lon': 121.0211},
#   'country': 'PH',
#   'population': 1000,
#   'timezone': 28800,
#   'sunrise': 1772489518,
#   'sunset': 1772532258}}

# %% [markdown]
# Let's place the result onto a `pandas` `DataFrame` for easier inspection and further analysis.

# %%
weather_forecast = pd.json_normalize(result['list'])
weather_forecast.dt_txt = pd.to_datetime(weather_forecast.dt_txt)
weather_forecast.loc[:, 'date_time'] = weather_forecast.dt_txt.dt.strftime('%a %d-%b %I %p')
weather_forecast.dtypes
# Out:
# dt                          int64
# weather                    object
# visibility                  int64
# pop                       float64
# dt_txt             datetime64[ns]
# main.temp                 float64
# main.feels_like           float64
# main.temp_min             float64
# main.temp_max             float64
# main.pressure               int64
# main.sea_level              int64
# main.grnd_level             int64
# main.humidity               int64
# main.temp_kf              float64
# clouds.all                  int64
# wind.speed                float64
# wind.deg                    int64
# wind.gust                 float64
# sys.pod                    object
# rain.3h                   float64
# date_time                  object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax2 = ax.twinx()

# Plot the chance of rain and feels like (temp)
weather_forecast.plot(kind='bar', x='date_time', y='pop', ax=ax, legend=False)
weather_forecast.plot(kind='line', x='date_time', y='main.feels_like', ax=ax2,
                      style='o-', lw=2.5, legend=False, color='tab:olive');

# Set xlim for proper context
ax.set_ylim(0, 1.)

# Reduce number of xticks for cleaner plot
xtick_labels = [text if not i % 3 else None for i, text in enumerate(ax.get_xticklabels())]
ax.tick_params(axis='x', pad=-1)
ax.set_xticklabels(xtick_labels, ha='right', rotation=45)

# Add axes labels
ax.set_ylabel("Percent Chance of Rain", fontsize=12, labelpad=15)
ax2.set_ylabel("Feels Like", fontsize=12, labelpad=15)
ax.set_xlabel("Day and Time", fontsize=12)
ax.set_title("5-Day Weather Forecast for Makati City", fontsize=14,
             weight='bold', pad=20);

# %% [markdown]
# ## 3 Google API

# %% [markdown]
# One of the most extensive collections of Web APIs available today is offered by Google. The **Google API**s ecosystem provides access to a wide range of services, including mapping tools, cloud computing resources, machine learning models, productivity applications, and more.
#
# In this final section, we will demonstrate how to authenticate and interact with a Google API, and explore how these services can be integrated into our own Python programs to retrieve data or leverage advanced functionalities.

# %% [markdown]
# ### Places API

# %% [markdown]
# To access Google APIs, we must first generate an API key for the specific service we intend to use. Each Google API requires proper authentication to ensure secure and authorized access.
#
# For this demonstration, we will use the **Places API**. To generate an API key, navigate to the official documentation page for the Places API and click the **“Get Started”** button. This will guide you through the process of creating or selecting a Google Cloud project, enabling the API, and generating your API credentials.
#
# Once you've acquired your API key, place them in the environment file `.env` with the name `PLACES_API_KEY`.
#
# Do also note the billings and pricing of the usage of Places API found in [Google Maps Pricing](https://developers.google.com/maps/billing-and-pricing/pricing).

# %% [markdown]
# ![Places API Billing](images/places_api_billing.PNG)

# %% [markdown]
# Places API allows for unlimited free usage for both **Places API Text Search Essentials (IDs Only)** and **Places API Place Details Essentials (IDs Only)**. Meanwhile, it has a usage cap of `10,000` calls per month for the other services.

# %% [markdown]
# #### Text Search

# %% [markdown]
# Let's demonstrate how we can use the **Text Search** functionality of the Places API. For more details on its usage, please see the [Text Search (New) Documentation](https://developers.google.com/maps/documentation/places/web-service/text-search).
#
# You'll notice that the required request for this is a `POST` request, as such, we will revise our request format accordingly.
#
# As an example, let's look for `ramen restaurants` near Makati.

# %%
endpoint = 'https://places.googleapis.com/v1/places:searchText'
data = {'textQuery': 'ramen restaurants',
        'locationBias': {
            'circle': {
                'center': {'latitude': lat, 'longitude': lon}, # Makati City
                'radius': 2_000 # in meters
            }
        }}
headers = {'Content-Type': 'application/json',
           'X-Goog-Api-Key': os.getenv('PLACES_API_KEY'),
           'X-Goog-FieldMask': 'places.attributions,places.id,places.name,nextPageToken,places.movedPlace,places.movedPlaceId'}

result = requests.post(endpoint, data=json.dumps(data), headers=headers)
result
# Out:
# <Response [200]>

# %%
result.json()
# Out:
# {'places': [{'name': 'places/ChIJF4IyqwfJlzMRTJYETLuK4dg',
#    'id': 'ChIJF4IyqwfJlzMRTJYETLuK4dg'},
#   {'name': 'places/ChIJR0l6ZwDJlzMR2flT_4VM61A',
#    'id': 'ChIJR0l6ZwDJlzMR2flT_4VM61A'},
#   {'name': 'places/ChIJlZgnmjbJlzMRd_s9XovL-uE',
#    'id': 'ChIJlZgnmjbJlzMRd_s9XovL-uE'},
#   {'name': 'places/ChIJ2Sa3iWLJlzMRWtcUEm9rfKs',
#    'id': 'ChIJ2Sa3iWLJlzMRWtcUEm9rfKs'},
#   {'name': 'places/ChIJtbcuexLJlzMRmzn8_XT8DPU',
#    'id': 'ChIJtbcuexLJlzMRmzn8_XT8DPU'},
#   {'name': 'places/ChIJPXAEYgDJlzMRCRiQxOHAnTE',
#    'id': 'ChIJPXAEYgDJlzMRCRiQxOHAnTE'},
#   {'name': 'places/ChIJ742WIAnJlzMRJ2Zukrqv4Ig',
#    'id': 'ChIJ742WIAnJlzMRJ2Zukrqv4Ig'},
#   {'name': 'places/ChIJWWQFP1rJlzMRcAC2yoPJRQs',
#    'id': 'ChIJWWQFP1rJlzMRcAC2yoPJRQs'},
#   {'name': 'places/ChIJN6xK2WvJlzMRQdKhEHTSxT0',
#    'id': 'ChIJN6xK2WvJlzMRQdKhEHTSxT0'},
#   {'name': 'places/ChIJIYckMqjJlzMRE1Sklc_IvLs',
#    'id': 'ChIJIYckMqjJlzMRE1Sklc_IvLs'},
#   {'name': 'places/ChIJqw8iAWTJlzMRig4qjv5P2EI',
#    'id': 'ChIJqw8iAWTJlzMRig4qjv5P2EI'},
#   {'name': 'places/ChIJ69YAWwDJlzMRFFT5x2sKXS8',
#    'id': 'ChIJ69YAWwDJlzMRFFT5x2sKXS8'},
#   {'name': 'places/ChIJiUOuZgDJlzMRK4VK1TwySHE',
#    'id': 'ChIJiUOuZgDJlzMRK4VK1TwySHE'},
#   {'name': 'places/ChIJ-UovMADJlzMRuu2pW2-jA88',
#    'id': 'ChIJ-UovMADJlzMRuu2pW2-jA88'},
#   {'name': 'places/ChIJGRjOWQDJlzMRbqvkfX9_l78',
#    'id': 'ChIJGRjOWQDJlzMRbqvkfX9_l78'},
#   {'name': 'places/ChIJ-cyvawDJlzMR3IsLioMogtc',
#    'id': 'ChIJ-cyvawDJlzMR3IsLioMogtc'},
#   {'name': 'places/ChIJPwRaEgDJlzMRzrAbrsyOrCg',
#    'id': 'ChIJPwRaEgDJlzMRzrAbrsyOrCg'},
#   {'name': 'places/ChIJT1WvnA_JlzMR6dlIhWZbPy4',
#    'id': 'ChIJT1WvnA_JlzMR6dlIhWZbPy4'},
#   {'name': 'places/ChIJZQz9ajvJlzMRWs3jE-ZBvZc',
#    'id': 'ChIJZQz9ajvJlzMRWs3jE-ZBvZc'},
#   {'name': 'places/ChIJpZQkc_LJlzMRBUUfiSJjnqE',
#    'id': 'ChIJpZQkc_LJlzMRBUUfiSJjnqE'}],
#  'nextPageToken': 'ATCDNfVQLNHFD8ZGW95OgDlgacxBgbxW0u5qGV9lMmOwMXf6fD2gXzKXeb2ZGro_xDA-1xm3DsXcEhgcyOBeiKxd6AXn63N-6O_AhqqIkf4T_Tr0SjQ0RvVVsgEkdran4uPu7bcoBa_wapmVpK7-eGcWwyx5--pX8t57nbWRoje9ukAbRzk2xHqNzHNCHy7NIrNSDlCffZCWG_ujYnuvMMrANH6eqwrq5zQrTLSNaNO9KkkWWZcvxwrXWlcz9ysCNK_Mr5Xb3S_OahfPaPi1BbrVrsTQUzS58B7OrRUJ8cmXpHKKa2a8f7l0ZoVHva1fSpsCX728w99m4vgTyR1IUcKtWH6GUdeb1rss2jEtkTlILWVid6np3jsld7hvyWlxQqx0hPxdC-NTfU-cQdMEgyGTV7yPJxwPEc7ZErq06WzTXtOOLkYhINnjdndoqv2t-dREYviWWMl1xxheWNkVShLycF2hBwfXAn9JX5Sgo8sJOnc02uGgFlvKyW8ZfzTtZeW7JLqwyS4_Rvnekp92iy4SsSE1k8ZSoQf-IOhMJthtY9OEF-UtAycAMs8_8DP2s5Y4frlQLaCKkSRPkpQlCb4uSd_n8YkNUoOCzmUfZypLSPoTrTU6z7UeQbZRu0M1gT8a9xy4hnPIcbhPSxlo-J6F6lcGm5Do8n4RyhpoNT0Qez0vmOI62kJqAah1_2vYRAAeq0IlWA1ikK3D8B4bFgGSRZ3Ua9nQsQZJkVH3gAGs-rPHTbyR9XcZtdRhJ-PizvtKQlSUbus2rTcpNW9e4fxRilEcDp8DuGh8qddIs2ROV_5av1yhRL1wWvIv5bVe5-O5grJjdYIajjE'}

# %% [markdown]
# Notice that we have retrieve `20` places as a result of our text query. There's also a `nextPageToken` which we can use to get the next page of the text search result. Let's store our search result on appropriately named variables.

# %%
ramen_places = result.json()['places']
next_page_token = result.json()['nextPageToken']

# %% [markdown]
# Let's retrieve the results on the next pages programatically.

# %%
endpoint = 'https://places.googleapis.com/v1/places:searchText'

for i in range(5):
    try:
        # Data Query and Headers
        data = {'textQuery': 'ramen restaurants',
                'locationBias': {
                    'circle': {
                        'center': {'latitude': lat, 'longitude': lon}, # Makati City
                        'radius': 2_000 # in meters
                    }},
                'pageToken': next_page_token
               }
        headers = {'Content-Type': 'application/json',
                   'X-Goog-Api-Key': os.getenv('PLACES_API_KEY'),
                   'X-Goog-FieldMask': 'places.attributions,places.id,places.name,nextPageToken,places.movedPlace,places.movedPlaceId'}

        # POST request
        result = requests.post(endpoint, data=json.dumps(data), headers=headers)

        # Try to append the result
        ramen_places.extend(result.json()['places'])
        next_page_token = result.json()['nextPageToken']

    except KeyError as e:
        print("Key not found: ", e)
        break
    else:
        print('Page: ', i + 2, 'Status Code: ', result.status_code)
        sleep(1)
# Out:
# Page:  2 Status Code:  200
# Key not found:  'nextPageToken'

# %%
ramen_places = pd.DataFrame(ramen_places).drop_duplicates()

# %%
len(ramen_places)
# Out:
# 60

# %% [markdown]
# In total, we gathered `60` ramen places from our query.

# %% [markdown]
# #### Place Details

# %% [markdown]
# Gathering the place `id` of a given text query is not very useful, as such, we proceed to gather further data about the details of our query using the **Place Details** functionality of the Places API. For this demonstration, we'll be triggering a ***Place Details Enterprise SKU***, which has a free usage of up to `1,000` calls each month. See screenshot below for more details:

# %% [markdown]
# ![Places API Enterprise](images/places_api_enterprise.PNG)

# %% [markdown]
# For this demonstration, we'll get the details for each of the `ramen places` we gathered from our previous text search query. We test it on the first place we've found from our text search.

# %%
ramen_places.iloc[0].id
# Out:
# 'ChIJF4IyqwfJlzMRTJYETLuK4dg'

# %%
endpoint = f'https://places.googleapis.com/v1/places/{ramen_places.iloc[0].id}'
fields = ['attributions', 'id', 'moved_place', 'moved_place_id', 'displayName',
          'photos', 'addressComponents', 'adrFormatAddress',
          'formattedAddress', 'location', 'plusCode', 'postalAddress',
          'shortFormattedAddress', 'types', 'viewport', 'currentOpeningHours',
          'currentSecondaryOpeningHours', 'nationalPhoneNumber',
          'internationalPhoneNumber', 'priceLevel', 'priceRange', 'rating',
          'regularOpeningHours', 'regularSecondaryOpeningHours',
          'userRatingCount', 'websiteUri']
headers = {'X-Goog-Api-Key': os.getenv('PLACES_API_KEY'),
           'X-Goog-FieldMask': ','.join(fields),
           'Content-Type': 'application/json'}

result = requests.get(endpoint, headers=headers)
result.status_code
# Out:
# 200

# %% [markdown]
# Let's store the result in a variable accordingly.

# %%
ramen_places_details = [result.json()]

# %%
with open('outputs/ramen_places.jsonl', 'a') as f:
    f.write(json.dumps(ramen_places_details[0]) + '\n')

# %% [markdown]
# Let's proceed to collect the place details of all the other places in our search result.

# %%
base_url = 'https://places.googleapis.com/v1/places/'
fields = ['attributions', 'id', 'moved_place', 'moved_place_id', 'displayName',
          'photos', 'addressComponents', 'adrFormatAddress',
          'formattedAddress', 'location', 'plusCode', 'postalAddress',
          'shortFormattedAddress', 'types', 'viewport', 'currentOpeningHours',
          'currentSecondaryOpeningHours', 'nationalPhoneNumber',
          'internationalPhoneNumber', 'priceLevel', 'priceRange', 'rating',
          'regularOpeningHours', 'regularSecondaryOpeningHours',
          'userRatingCount', 'websiteUri']
headers = {'X-Goog-Api-Key': os.getenv('PLACES_API_KEY'),
           'X-Goog-FieldMask': ','.join(fields),
           'Content-Type': 'application/json'}

for i, ramen_place in ramen_places.iloc[1:].iterrows():
    endpoint = f'{base_url}{ramen_place.id}'

    try:
        response = requests.get(endpoint, headers=headers)
        sleep(0.5)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Failed request for {ramen_place.id}: ", e)
    else:
        print(f"Request success for {ramen_place.id}")
        ramen_places_details.append(response.json())
        with open('outputs/ramen_places.jsonl', 'a') as f:
            f.write(json.dumps(ramen_places_details[-1]) + '\n')
# Out:
# Request success for ChIJR0l6ZwDJlzMR2flT_4VM61A
# Request success for ChIJlZgnmjbJlzMRd_s9XovL-uE
# Request success for ChIJ2Sa3iWLJlzMRWtcUEm9rfKs
# Request success for ChIJtbcuexLJlzMRmzn8_XT8DPU
# Request success for ChIJPXAEYgDJlzMRCRiQxOHAnTE
# Request success for ChIJ742WIAnJlzMRJ2Zukrqv4Ig
# Request success for ChIJWWQFP1rJlzMRcAC2yoPJRQs
# Request success for ChIJN6xK2WvJlzMRQdKhEHTSxT0
# Request success for ChIJIYckMqjJlzMRE1Sklc_IvLs
# Request success for ChIJqw8iAWTJlzMRig4qjv5P2EI
# Request success for ChIJ69YAWwDJlzMRFFT5x2sKXS8
# Request success for ChIJiUOuZgDJlzMRK4VK1TwySHE
# Request success for ChIJ-UovMADJlzMRuu2pW2-jA88
# Request success for ChIJGRjOWQDJlzMRbqvkfX9_l78
# Request success for ChIJ-cyvawDJlzMR3IsLioMogtc
# Request success for ChIJPwRaEgDJlzMRzrAbrsyOrCg
# Request success for ChIJT1WvnA_JlzMR6dlIhWZbPy4
# Request success for ChIJZQz9ajvJlzMRWs3jE-ZBvZc
# Request success for ChIJpZQkc_LJlzMRBUUfiSJjnqE
# Request success for ChIJVXV_TwzJlzMRFhdeS8Ncygk
# Request success for ChIJ4x5qO-nJlzMR4aFfiws8tIo
# Request success for ChIJobtL3brJlzMR9b7Ucsi7jmU
# Request success for ChIJmZPXIrTJlzMR1f7riRbJzrM
# Request success for ChIJ-wxyLH7JlzMR8PdtmRDAn2Q
# Request success for ChIJr54X4tLJlzMR5-wD89v7ydE
# Request success for ChIJJ2tYQgDJlzMRHLoJb0653j8
# Request success for ChIJww8n7hDJlzMR1C4tF5aQ2Jk
# Request success for ChIJ2-7n1AbJlzMRUwQmh7iT99c
# Request success for ChIJp9UWRgDJlzMRplHcEAfUKhM
# Request success for ChIJFVHQGwDJlzMRfByxzWPgh7E
# Request success for ChIJ-aWKpyDJlzMRbYlOUmkAXrY
# Request success for ChIJNcsjnKTJlzMRq6kzxt0dllc
# Request success for ChIJ5amuaPXJlzMREe29fw6E8Ao
# Request success for ChIJwWi2rdG3lzMRVZPkB1mBWis
# Request success for ChIJ7zOoDBDJlzMRIvYk9P3kl9E
# Request success for ChIJfU3kDz_JlzMRfK_MGTkI-2k
# Request success for ChIJ9TWrHZDJlzMRC3zbJMH3Q2I
# Request success for ChIJFxdY1wvJlzMRPkGpmmyVj78
# Request success for ChIJuYqw6UzJlzMRgAlUl0ci8Ic
# Request success for ChIJcZYiPqnJlzMRxo6-PXQUvew
# Request success for ChIJ-9P8l0TJlzMRUQMe982TAt4
# Request success for ChIJtR4D4JXJlzMRQ6-rCXnBlS0
# Request success for ChIJWV2OfnvJlzMRlEocxzaU6Ok
# Request success for ChIJmVKHVF3IlzMRhd0JOpDjR-8
# Request success for ChIJa2RIyETJlzMRG7wpuAh6vnY
# Request success for ChIJPaQFscPJlzMRujdxjtGPuMo
# Request success for ChIJSxDY6tO3lzMRsgnudeYzesQ
# Request success for ChIJkdbOR6XJlzMRHkVFhLc_otk
# Request success for ChIJSUt-ZUjIlzMRS1WDs7qhDXE
# Request success for ChIJz7GUB_XIlzMRNsm9Sd7WKag
# Request success for ChIJ1fb96d7JlzMRTbDS0kNkan8
# Request success for ChIJp7g_GwDLlzMRtV5Ls4bmSJc
# Request success for ChIJ0Q5fZgDJlzMRorzEBAJ9Fcw
# Request success for ChIJrZlBi8TJlzMRjwAl4YaPM3o
# Request success for ChIJwZhPasnJlzMRiQUXjWrZs1o
# Request success for ChIJuwEG4ijKlzMRA_af45Qyszc
# Request success for ChIJCYwgBsvOlzMRF6fdLiV_JlU
# Request success for ChIJA3hH4LfLlzMRr8AtkWhbaXQ
# Request success for ChIJk9e-qNHJlzMRK0x2GQfsW-c

# %% [markdown]
# Let's digest the result into a `pandas` `DataFrame` for succeeding analysis.

# %%
ramen_places_df = []
for ramen_place_detail in ramen_places_details:
    ramen_places_df.append({
        'name': ramen_place_detail.get('displayName', {'text': None})['text'],
        'address': ramen_place_detail.get('formattedAddress', None),
        'phone_number': ramen_place_detail.get('internationalPhoneNumber', None),
        'rating': ramen_place_detail.get('rating', None),
        'rating_count': ramen_place_detail.get('userRatingCount', None),
        'price_range_start': ramen_place_detail.get('priceRange', {'startPrice': {'units': None}})['startPrice']['units'],
        'price_range_end': ramen_place_detail.get('priceRange', {'endPrice': {'units': None}})['endPrice']['units']
    })
ramen_places_df = pd.DataFrame(ramen_places_df)

# %% [markdown]
# Now that we have the details of all of the ramen places near Makati, let's find out which place would be a good place to eat ramen. Let's sort the result according to highest `rating`, `rating_count`, and decreasing `price_range_start`. Let's also filter the restaurants which has `rating_count` less than `100`.

# %%
ramen_places_df[ramen_places_df.rating_count >= 100].sort_values(
    by=['rating', 'rating_count', 'price_range_start'],
    ascending=[False, False, True]).head(10)
# Out:
#                                       name  \
# 43  Menya Kokoro Ramen Izakaya Uptown Mall
# 21                      Ramen Ron Rockwell
# 32                           Ramen Ron BGC
# 58                                Tsukemen
# 23                               Gatsu-man
# 47                       Hanamaruken Ramen
# 12           Fujiyama 55 Ramen Philippines
# 9                  Ramen Ibuki, Uptown BGC
# 52    Tonkotsu Kazan Ramen SM Mall of Asia
# 27         Musashi-Tei Japanese Restaurant
#
#                                               address      phone_number  \
# 43         9th Ave, Taguig, Metro Manila, Philippines   +63 2 7758 6493
# 21  GF, RS-103, Edades Tower Rockwell Center Makat...  +63 917 628 7245
# 32  Ground Floor, Bonifacio High Street - Central ...  +63 917 136 1991
# 58  GXMJ+XP7, Seaside Blvd, 123, Pasay City, 1300 ...              None
# 23         9th Ave, Taguig, Metro Manila, Philippines              None
# 47  Santolan Town Plaza, Col. ボニー・セラーノ・アベニュー San J...              None
# 12  Building 6, EDSA, corner, 1100 McKinley Rd, Ma...              None
# 9   Uptown Parade, 9th Ave, Bonifacio Global City,...  +63 917 191 3888
# 52  Level 1, North Entertainment Mall, SM Mall of ...              None
# 27  Level 3, Al Fresco, One Ayala, 1 Ayala Ave, Ma...  +63 956 045 1678
#
#     rating  rating_count price_range_start price_range_end
# 43     4.8          2131               500            1000
# 21     4.8          1722               500            1000
# 32     4.8          1640               500            1000
# 58     4.8           936                 1             500
# 23     4.8           916                 1             500
# 47     4.8           765               500            1000
# 12     4.8           462               500            1000
# 9      4.8           381               500            1000
# 52     4.8           173                 1             500
# 27     4.7           180               500            1000

# %% [markdown]
# <img src="images/banner-down.png" style="width: 100%;">
