# %% [markdown]
# <img src="images/banner.png" style="width: 100%;">

# %% [markdown]
# # Web Scraping with Python

# %%
# !conda install html5lib -y # You might need to instll html5lib for the proper HTML parsing

# %% [markdown]
# References:
#
# [1] Mitchell, Ryan. *Web scraping with python.* " O'Reilly Media, Inc.", 2024.
#
# [2] Chapagain, Anish. *Hands-On Web Scraping with Python: Extract quality data from the web using effective Python techniques.* Packt Publishing Ltd, 2023.
#
# [3] Elridge, Taryn. *Web automation and scraping with Python: Hands-on mastery of selenium, beautifulsoup, and real-world data extraction.* 2025.
#
# [4] Requests Documentation - https://requests.readthedocs.io/en/latest/user/quickstart/
#
# [5] Beautiful Soup Documentation - https://beautiful-soup-4.readthedocs.io/en/latest/
#
# [6] Revised and grammar checked using ChatGPT - https://chatgpt.com/

# %% [markdown]
# Prepared by: Leodegario Lorenzo II

# %% [markdown]
# This notebook introduces the fundamentals of web scraping using Python and the `BeautifulSoup` library.
#
# In a nutshell, **web scraping** is the process of extracting data from websites programmatically. In other words, we’ll use Python to interact with web pages the way a human would through a browser—requesting pages, reading their content, and pulling out the information we care about.
#
# In this demo, we’ll walk through:
#
# 1. How to make HTTP requests with Python
# 2. How to parse and navigate HTML documents with BeautifulSoup
# 3. Common design patterns and best practices for more advanced web scraping tasks
#
# By the end, you should have a solid fundamentals for how web scraping works and the confidence to build your own scrapers responsibly.

# %% [markdown]
# ## 0 Web Scraping Prerequisites

# %% [markdown]
# ### `robots.txt`

# %% [markdown]
# Before scraping any website, you should first check the site’s `robots.txt` file. This file indicates which parts of the site the owner allows or disallows for automated access. Reviewing it helps you avoid scraping areas the site explicitly asks bots not to access, and sets a baseline for responsible, respectful scraping practices.

# %% [markdown]
# For most of the initial examples in this notebook, we'll be scraping the website from one of our primary reference - [pythonscraping.com](https://pythonscraping.com/). A quick look on its `robots.txt` file indicate that most of the pages are allowed for scraping, except for particular files and login-protected directories:
#
# ```
# #
# # robots.txt
# #
# # This file is to prevent the crawling and indexing of certain parts
# # of your site by web crawlers and spiders run by sites like Yahoo!
# # and Google. By telling these "robots" where not to go on your site,
# # you save bandwidth and server resources.
# #
# # This file will be ignored unless it is at the root of your host:
# # Used:    http://example.com/robots.txt
# # Ignored: http://example.com/site/robots.txt
# #
# # For more information about the robots.txt standard, see:
# # http://www.robotstxt.org/robotstxt.html
# #
# # For syntax checking, see:
# # http://www.frobee.com/robots-txt-check
#
# User-agent: *
# Crawl-delay: 10
# # Directories
# Disallow: /includes/
# Disallow: /misc/
# Disallow: /modules/
# Disallow: /profiles/
# Disallow: /scripts/
# Disallow: /themes/
# # Files
# Disallow: /CHANGELOG.txt
# Disallow: /cron.php
# Disallow: /INSTALL.mysql.txt
# Disallow: /INSTALL.pgsql.txt
# Disallow: /INSTALL.sqlite.txt
# Disallow: /install.php
# Disallow: /INSTALL.txt
# Disallow: /LICENSE.txt
# Disallow: /MAINTAINERS.txt
# Disallow: /update.php
# Disallow: /UPGRADE.txt
# Disallow: /xmlrpc.php
# # Paths (clean URLs)
# Disallow: /admin/
# Disallow: /comment/reply/
# Disallow: /filter/tips/
# Disallow: /node/add/
# Disallow: /search/
# Disallow: /user/register/
# Disallow: /user/password/
# Disallow: /user/login/
# Disallow: /user/logout/
# # Paths (no clean URLs)
# Disallow: /?q=admin/
# Disallow: /?q=comment/reply/
# Disallow: /?q=filter/tips/
# Disallow: /?q=node/add/
# Disallow: /?q=search/
# Disallow: /?q=user/password/
# Disallow: /?q=user/register/
# Disallow: /?q=user/login/
# Disallow: /?q=user/logout/
# ```

# %% [markdown]
# We should also note that the recommended `crawl-delay` for this website is `10` seconds, and we should adhere to this as much as possible.

# %% [markdown]
# ### Specifying the `User-Agent`

# %% [markdown]
# Aside from following the site’s `robots.txt` rules, it’s also good practice to identify your scraper when making requests by setting a clear `User-Agent` header. This lets website owners know who (or what) is accessing their site and helps your requests look like responsible traffic rather than anonymous or potentially malicious activity.

# %%
headers = {"User-Agent": "llorenzo-scraper/1.0(contact:llorenzo@aim.edu)"}

# %% [markdown]
# ## 1 Performing HTTP requests using `requests`

# %% [markdown]
# `requests` is a simple HTTP library for Python which we will use to send client requests and interpret server responses programatically.

# %% [markdown]
# ### General Usage

# %% [markdown]
# Let's look at some key features of the `requests` library.

# %%
from time import sleep

import requests

# %% [markdown]
# First, we demonstrate how we perform **GET** requests using `requests`.

# %%
url = 'http://pythonscraping.com/pages/page1.html'

response = requests.get(url, headers=headers)
sleep(10)

# %% [markdown]
# The above code generates a GET request from our client then the server response is collected into the variable `response`.

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# The output is a `Response` object which has several useful attributes. First, we can check for the status code of the response:

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# There are several possible status codes, each of which describes the result of the requests. We list some of the important status codes below:

# %% [markdown]
# | Code | Description |
# | :--- | :---------- |
# | `200` | OK, request succeed |
# | `404` | Not found, requested resource cannot be found |
# | `403` | Access denied |
# | `429` | Too many requests (rate-limited) |
# | `500` | Internal server error |

# %% [markdown]
# If you encounter an HTTP status error, you’ll want to handle it gracefully so you can control how your program behaves when something goes wrong.
#
# In practice, this usually means logging the error (for example, to a file) and deciding whether to retry, skip the request, or stop the program altogether. A common pattern you’ll see is using try–except blocks to catch and handle these errors cleanly.

# %%
url = 'http://pythonscraping.com/pages/page1337.html'
headers = {"User-Agent": "llorenzo-scraper/1.0(contact:llorenzo@aim.edu)"}

try:
    response = requests.get(url, headers=headers)
    sleep(10)
    response.raise_for_status()
except requests.RequestException as e:
    print("Failed to fetch page: ", e)
# Out:
# Failed to fetch page:  404 Client Error: Not Found for url: https://pythonscraping.com/pages/page1337.html

# %% [markdown]
# We will be using the above code multiple times throughout this notebook, thus, we might as well create a function for obtaining responses when we request for web pages.

# %%
def get_webpage(url, headers, sleep_time=10):
    """Perform GET request on a given url then collect the resulting
    response

    Parameters
    ----------
    url : str
        URL string of the website to be scraped
    headers : dict
        Set of key-value pairs to be passed as headers during the
        request
    sleep_time : numeric, default=10
        Delay time after the request

    Returns
    -------
    response : Response object
        Response of the server to the request
    """
    try:
        response = requests.get(url, headers=headers)
        sleep(sleep_time)
        response.raise_for_status()
    except requests.RequestException as e:
        print("Failed to fetch page: ", e)
    else:
        print(f"Page has been successfully fetched! {url}")

    return response

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# ## 2 Web Scraping using `BeautifulSoup`

# %% [markdown]
# Now that we know how we can create requests from our client using Python, the next step is knowing how to parse the resulting HTML content and extract the data that we want from the website.

# %% [markdown]
# ### Basic Usage of `BeautifulSoup`

# %% [markdown]
# Let's first get once again the `page1.html` from the `pythonscraping` website which contains a simple html file.

# %%
url = 'http://pythonscraping.com/pages/page1.html'
response = get_webpage(url, headers)
# Out:
# Page has been successfully fetched!

# %% [markdown]
# We can get the contents of the HTML file by calling the `content` attribute. Verify that the content is usually an HTML file. On usual requests you would get an HTML file, but there are websites also where the output can be of other format such as `xml` or `json` files.

# %%
response.content
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %% [markdown]
# We can then use Beautiful Soup (`bs4`) to parse this HTML file. The most comonly used object in `bs4` is the `BeautifulSoup` object, which we import accordingly.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# When we use the `BeautifulSoup` object, we specify two parameters - the first is the HTML string object to parse, while the second specifies the parser that you want Beautiful Soup to use.
#
# The currently supported parsers are `html.parser` (Python's built-in HTML parser), `lxml`, `html5lib`. Different parsers will create different parse trees from the same document. For more info please check the [documentation](https://beautiful-soup-4.readthedocs.io/en/latest/#differences-between-parsers).
#
# If given a perfectly formed HTML, the data structure will be identical for different parsers. But if the HTML is not perfectly-formed, different parsers will give different results. Among the html parsers, the `html5lib` parser uses techniques that are part of the `HTML5` standard. Thus, this is what we'll be using on most of our examples.

# %%
soup = BeautifulSoup(response.content, 'html5lib')

# %% [markdown]
# Afterwards, the HTML will be parsed into an object with a hierarchical structure:

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A Useful Page
#   </title>
#  </head>
#  <body>
#   <h1>
#    An Interesting Title
#   </h1>
#   <div>
#    Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
#   </div>
#  </body>
# </html>

# %% [markdown]
# The `BeautifulSoup` object represents the HTML document as a whole, meanwhile, a `Tag` object corresponds to an HTML tag in the original document.

# %%
soup.html
# Out:
# <html><head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
#
#
# </body></html>

# %%
type(soup.html)
# Out:
# bs4.element.Tag

# %% [markdown]
# You can traverse the document in one direction by chaining method calls of corresponding children tags.

# %%
soup.html.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# Each tag also has the `name` accessible as `.name`:

# %%
soup.html.body.h1.name
# Out:
# 'h1'

# %% [markdown]
# And you can extract the text within a tag using the `.text` attribute.

# %%
soup.html.body.h1.text
# Out:
# 'An Interesting Title'

# %% [markdown]
# Or you can opt to use the `.get_text()` function for better readability.

# %%
soup.html.body.h1.get_text()
# Out:
# 'An Interesting Title'

# %% [markdown]
# ### Finding tags

# %% [markdown]
# To filter HTML pages and find only a list of desired elements, `BeautifulSoup` provides us with the `find()` and `find_all()` function.
#
# - `find()` returns the first match. e.g. `soup.find('a')` returns the first HTML element with a `a` tag.
# - `find_all()` returns a list of all matches. `soup.find_all('a')` returns an iterable of HTML elements with a `a` tag.

# %% [markdown]
# You can define filters as a string, regular expression, or a list, which matches the given input to the tag of the corresponding HTML element. The definition of the two functions is as follows:
#
# ```
# find_all(tag, attrs, recursive, text, limit, **kwargs)
# find(tag, attrs, recursive, text, **kwargs)
# ```

# %% [markdown]
# As an example of the usage of `find()` and `find_all()`, let's look at scraping the web page http://www.pythonscraping.com/pages/warandpeace.html

# %%
url = 'http://www.pythonscraping.com/pages/warandpeace.html'

response = get_webpage(url, headers)
# Out:
# Page has been successfully fetched!

# %% [markdown]
# After successfully fetching the page, we proceed to create a `BeautifulSoup` object:

# %%
soup = BeautifulSoup(response.content, 'html5lib')

# %% [markdown]
# You'll notice that the spoken lines of the characters in the stories are highlighted in red, meanwhile the names of the characters are in green.

# %%
for line in soup.prettify().splitlines()[78: 85]:
    print(line)
# Out:
#      Heavens! what a virulent attack!
#     </span>
#     " replied
#     <span class="green">
#      the prince
#     </span>
#     , not in the

# %% [markdown]
# As such, we can extract all the character names by filtering all `span` elements with `class` having a value of `green`.

# %%
character_list = soup.find_all('span', {'class': 'green'})
set([element.text.lower().replace('\n', ' ') for element in character_list])
# Out:
# {'abbe morio',
#  'anatole',
#  'anna pavlovna',
#  'anna pavlovna scherer',
#  "anna pavlovna's",
#  'baron funke',
#  'dowager empress marya fedorovna',
#  'empress marya fedorovna',
#  'her majesty',
#  'king of prussia',
#  'le vicomte de mortemart',
#  'montmorencys',
#  'prince vasili',
#  'prince vasili kuragin',
#  'rohans',
#  'st. petersburg',
#  'the baron',
#  'the emperor',
#  'the empress',
#  'the prince',
#  'wintzingerode'}

# %% [markdown]
# ### Navigating Trees

# %% [markdown]
# Recall that chaining tags enables you to navigate the `BeautifulSoup` tree in a single downward direction:

# %%
soup.body.div.p
# Out:
# <p>
# It was in July, 1805, and the speaker was the well-known <span class="green">Anna
# Pavlovna Scherer</span>, maid of honor and favorite of the <span class="green">Empress Marya
# Fedorovna</span>. With these words she greeted <span class="green">Prince Vasili Kuragin</span>, a man
# of high rank and importance, who was the first to arrive at her
# reception. <span class="green">Anna Pavlovna</span> had had a cough for some days. She was, as
# she said, suffering from la grippe; grippe being then a new word in
# <span class="green">St. Petersburg</span>, used only by the elite.
# </p>

# %% [markdown]
# If we want to get all the `<p>` tags within the first `<div>` tag in the document, or anything more complicated than the first tag within a certain level, we would need to use other methods to do so.
#
# In the next subsection, we show how we can also traverse the tree further with more control using various attributes and functions. We'll demonstrate how to navigate the tree downards, upwards, and sideways.

# %% [markdown]
# #### Going down

# %% [markdown]
# If we want to get all the tags directly one below a certain tag, we can use the `.contents` or `.children` attribute.

# %%
soup.body.div.p.contents
# Out:
# ['\nIt was in July, 1805, and the speaker was the well-known ',
#  <span class="green">Anna
#  Pavlovna Scherer</span>,
#  ', maid of honor and favorite of the ',
#  <span class="green">Empress Marya
#  Fedorovna</span>,
#  '. With these words she greeted ',
#  <span class="green">Prince Vasili Kuragin</span>,
#  ', a man\nof high rank and importance, who was the first to arrive at her\nreception. ',
#  <span class="green">Anna Pavlovna</span>,
#  ' had had a cough for some days. She was, as\nshe said, suffering from la grippe; grippe being then a new word in\n',
#  <span class="green">St. Petersburg</span>,
#  ', used only by the elite.\n']

# %%
list(soup.body.div.p.children)
# Out:
# ['\nIt was in July, 1805, and the speaker was the well-known ',
#  <span class="green">Anna
#  Pavlovna Scherer</span>,
#  ', maid of honor and favorite of the ',
#  <span class="green">Empress Marya
#  Fedorovna</span>,
#  '. With these words she greeted ',
#  <span class="green">Prince Vasili Kuragin</span>,
#  ', a man\nof high rank and importance, who was the first to arrive at her\nreception. ',
#  <span class="green">Anna Pavlovna</span>,
#  ' had had a cough for some days. She was, as\nshe said, suffering from la grippe; grippe being then a new word in\n',
#  <span class="green">St. Petersburg</span>,
#  ', used only by the elite.\n']

# %% [markdown]
# If you want to go deeper than one level, you can use the `.descendants` function instead.

# %%
list(soup.body.div.p.descendants)
# Out:
# ['\nIt was in July, 1805, and the speaker was the well-known ',
#  <span class="green">Anna
#  Pavlovna Scherer</span>,
#  'Anna\nPavlovna Scherer',
#  ', maid of honor and favorite of the ',
#  <span class="green">Empress Marya
#  Fedorovna</span>,
#  'Empress Marya\nFedorovna',
#  '. With these words she greeted ',
#  <span class="green">Prince Vasili Kuragin</span>,
#  'Prince Vasili Kuragin',
#  ', a man\nof high rank and importance, who was the first to arrive at her\nreception. ',
#  <span class="green">Anna Pavlovna</span>,
#  'Anna Pavlovna',
#  ' had had a cough for some days. She was, as\nshe said, suffering from la grippe; grippe being then a new word in\n',
#  <span class="green">St. Petersburg</span>,
#  'St. Petersburg',
#  ', used only by the elite.\n']

# %% [markdown]
# If we only want to get only the strings or text within the text of the descendants of a tag, we can use the `.strings` method.

# %%
list(soup.body.div.p.strings)
# Out:
# ['\nIt was in July, 1805, and the speaker was the well-known ',
#  'Anna\nPavlovna Scherer',
#  ', maid of honor and favorite of the ',
#  'Empress Marya\nFedorovna',
#  '. With these words she greeted ',
#  'Prince Vasili Kuragin',
#  ', a man\nof high rank and importance, who was the first to arrive at her\nreception. ',
#  'Anna Pavlovna',
#  ' had had a cough for some days. She was, as\nshe said, suffering from la grippe; grippe being then a new word in\n',
#  'St. Petersburg',
#  ', used only by the elite.\n']

# %% [markdown]
# Or `.stripped_strings` if we want to delete the trailing and leading whitespaces in each strings.

# %%
list(soup.body.div.p.stripped_strings)
# Out:
# ['It was in July, 1805, and the speaker was the well-known',
#  'Anna\nPavlovna Scherer',
#  ', maid of honor and favorite of the',
#  'Empress Marya\nFedorovna',
#  '. With these words she greeted',
#  'Prince Vasili Kuragin',
#  ', a man\nof high rank and importance, who was the first to arrive at her\nreception.',
#  'Anna Pavlovna',
#  'had had a cough for some days. She was, as\nshe said, suffering from la grippe; grippe being then a new word in',
#  'St. Petersburg',
#  ', used only by the elite.']

# %% [markdown]
# #### Going Up

# %% [markdown]
# You can also access an element's parent with the `.parent` attribute.

# %%
soup.body.div.p.span.parent
# Out:
# <p>
# It was in July, 1805, and the speaker was the well-known <span class="green">Anna
# Pavlovna Scherer</span>, maid of honor and favorite of the <span class="green">Empress Marya
# Fedorovna</span>. With these words she greeted <span class="green">Prince Vasili Kuragin</span>, a man
# of high rank and importance, who was the first to arrive at her
# reception. <span class="green">Anna Pavlovna</span> had had a cough for some days. She was, as
# she said, suffering from la grippe; grippe being then a new word in
# <span class="green">St. Petersburg</span>, used only by the elite.
# </p>

# %% [markdown]
# #### Going Sideways

# %% [markdown]
# We can also use the `.next_sibling` and `.previous_sibling` to navigate between page elements that are on the same level of the parse tree:

# %%
soup.div.p.next_sibling
# Out:
# <p>
# All her invitations without exception, written in French, and
# delivered by a scarlet-liveried footman that morning, ran as follows:
# </p>

# %%
soup.div.p.previous_sibling
# Out:
# '"\n'

# %% [markdown]
# Or if we want to list all the tags within the same level of the current tag, we can use `.next_siblings` or `.previous_siblings`

# %%
list(soup.div.p.next_siblings)[:2]
# Out:
# [<p>
#  All her invitations without exception, written in French, and
#  delivered by a scarlet-liveried footman that morning, ran as follows:
#  </p>,
#  <p>
#  "<span class="red">If you have nothing better to do, Count [or Prince], and if the
#  prospect of spending an evening with a poor invalid is not too
#  terrible, I shall be very charmed to see you tonight between 7 and 10-
#  Annette Scherer.</span>"
#  </p>]

# %% [markdown]
# <div class="alert alert-info" role="info">
#
#   <b>Example 1: A Totally Normal Gifts Website</b>
#
#   Retrieve and extract the item titles, description, cost, and image url of the gifts found from the website https://www.pythonscraping.com/pages/page3.html. Place the result in a `pandas` `DataFrame`.
#
# </div>

# %%
import pandas as pd

# %%
url = 'https://www.pythonscraping.com/pages/page3.html'

response = get_webpage(url, headers)
# Out:
# Page has been successfully fetched!

# %%
soup = BeautifulSoup(response.content, 'html5lib')

# %%
gifts = []
for i, element in enumerate(soup.tr.find_next_siblings('tr')):
    row = [' '.join(elem.stripped_strings) for elem in element.children]
    row[-1] = list(element.children)[-1].img['src']
    gifts.append(row)
gifts = pd.DataFrame(gifts, columns=['item', 'description', 'cost', 'image_url'])
gifts
# Out:
#                     item                                        description  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#          cost              image_url
# 0      $15.00  ../img/gifts/img1.jpg
# 1  $10,000.52  ../img/gifts/img2.jpg
# 2  $10,005.00  ../img/gifts/img3.jpg
# 3       $0.50  ../img/gifts/img4.jpg
# 4       $1.50  ../img/gifts/img6.jpg

# %%
gifts.loc[:, 'cost'] = gifts.cost.str[1:].str.replace(',', '').astype(float)
gifts
# Out:
#                     item                                        description  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#        cost              image_url
# 0      15.0  ../img/gifts/img1.jpg
# 1  10000.52  ../img/gifts/img2.jpg
# 2   10005.0  ../img/gifts/img3.jpg
# 3       0.5  ../img/gifts/img4.jpg
# 4       1.5  ../img/gifts/img6.jpg

# %% [markdown]
# ## 3 Advanced Data Extraction with `BeautifulSoup`

# %% [markdown]
# We have demonstrated the basic features of `BeautifulSoup` which involves finding and accessing tags and attributes. We build on these tools further by introducing CSS selectors for precise targetting then also showing how we can also extract multiple pages or even multiple sites.

# %% [markdown]
# ### CSS Selectors

# %% [markdown]
# CSS selectors can select elements baed on tags, classes, IDs, or attributes. The basic CSS selector syntax is as follows:
#
# - `tag`: Selects all `<tag>` elements
# - `.class`: Selects elements with `class="class"`
# - `#id`: Selects an element with `id="id"`
# - `[attribute="value"]`: Selects an element with the specified attribute.
#
# You can use CSS selectors using `BeautifulSoup` through the `select()` method.

# %% [markdown]
# As an example, we select specific elements on the previously scraped website.

# %%
soup.select('tr#gift2')
# Out:
# [<tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>]

# %% [markdown]
# <div class="alert alert-info" role="info">
#
#   <b>Example 2: A Totally Normal Gifts Website</b>
#
#   Retrieve and extract the item titles, description, cost, and image url of the gifts found from the website https://www.pythonscraping.com/pages/page3.html using **CSS selectors**. Place the result in a `pandas` `DataFrame`.
#
# </div>

# %%
gifts = []
for table_row in soup.select('tr.gift'):
    row = [' '.join(data.stripped_strings) for data in table_row.select('td')]
    row[-1] = table_row.select_one('img')['src']
    gifts.append(row)
gifts = pd.DataFrame(gifts, columns=['item', 'description', 'cost', 'image_url'])
gifts
# Out:
#                     item                                        description  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#          cost              image_url
# 0      $15.00  ../img/gifts/img1.jpg
# 1  $10,000.52  ../img/gifts/img2.jpg
# 2  $10,005.00  ../img/gifts/img3.jpg
# 3       $0.50  ../img/gifts/img4.jpg
# 4       $1.50  ../img/gifts/img6.jpg

# %% [markdown]
# ### Scraping Multiple Webpages or Websites

# %% [markdown]
# So far, our examples have focused on extracting data from static web pages. Now that we know how to locate and extract specific tags and attributes, we can extend this idea to collect all the URLs on a page and then scrape each newly discovered page in turn.
#
# Programs that follow links and move from page to page in this way are called **web crawlers**, since they “crawl” across the web by traversing links between pages.

# %% [markdown]
# As an example, let's demonstrate how we can create our own ***Pokédex™*** by extracting multiple webpages from a pokemon website - https://pokemondb.net/
#
# Looking at the `https://pokemondb.net/robots.txt` file, the website disallows bots only on specific pages:
#
# ```
# User-agent: *
# Disallow: /pokebase/search?
# Disallow: /pokebase/revisions
# Disallow: /pokebase/meta/search?
# Disallow: /pokebase/meta/revisions
# Disallow: /pokebase/rmt/search?
# Disallow: /pokebase/rmt/revisions
# Crawl-delay: 2
# ```
#
# We also note the crawl delay value of `2` for the website.
#
# Specifically, let's scrape and create a database for the **FireRed & LeafGreen** version of Pokemon.

# %%
url = 'https://pokemondb.net/pokedex/game/firered-leafgreen'
headers = {"User-Agent": "llorenzo-scraper/1.0(contact:llorenzo@aim.edu)"}

response = get_webpage(url, headers=headers, sleep_time=5)
# Out:
# Page has been successfully fetched!

# %%
soup = BeautifulSoup(response.content, 'html5lib')

# %%
pokemons = []
for elem in soup.select('div.infocard'):
    pokemons.append({
        'pokemon_id': elem.small.text,
        'name': elem.select_one('a.ent-name').text,
        'type': ','.join([itype.text for itype in elem.select('a.itype')]),
        'image_url': elem.img['src'],
        'pokedex_url': f'https://pokemondb.net/{elem.a['href']}'
    })
pokemons = pd.DataFrame(pokemons)

# %%
pokemons
# Out:
#     pokemon_id        name           type  \
# 0         #001   Bulbasaur   Grass,Poison
# 1         #002     Ivysaur   Grass,Poison
# 2         #003    Venusaur   Grass,Poison
# 3         #004  Charmander           Fire
# 4         #005  Charmeleon           Fire
# ..         ...         ...            ...
# 146       #147     Dratini         Dragon
# 147       #148   Dragonair         Dragon
# 148       #149   Dragonite  Dragon,Flying
# 149       #150      Mewtwo        Psychic
# 150       #151         Mew        Psychic
#
#                                              image_url  \
# 0    https://img.pokemondb.net/sprites/ruby-sapphir...
# 1    https://img.pokemondb.net/sprites/ruby-sapphir...
# 2    https://img.pokemondb.net/sprites/ruby-sapphir...
# 3    https://img.pokemondb.net/sprites/ruby-sapphir...
# 4    https://img.pokemondb.net/sprites/ruby-sapphir...
# ..                                                 ...
# 146  https://img.pokemondb.net/sprites/ruby-sapphir...
# 147  https://img.pokemondb.net/sprites/ruby-sapphir...
# 148  https://img.pokemondb.net/sprites/ruby-sapphir...
# 149  https://img.pokemondb.net/sprites/ruby-sapphir...
# 150  https://img.pokemondb.net/sprites/ruby-sapphir...
#
#                                    pokedex_url
# 0     https://pokemondb.net//pokedex/bulbasaur
# 1       https://pokemondb.net//pokedex/ivysaur
# 2      https://pokemondb.net//pokedex/venusaur
# 3    https://pokemondb.net//pokedex/charmander
# 4    https://pokemondb.net//pokedex/charmeleon
# ..                                         ...
# 146     https://pokemondb.net//pokedex/dratini
# 147   https://pokemondb.net//pokedex/dragonair
# 148   https://pokemondb.net//pokedex/dragonite
# 149      https://pokemondb.net//pokedex/mewtwo
# 150         https://pokemondb.net//pokedex/mew
#
# [151 rows x 5 columns]

# %% [markdown]
# Let's populate our pokedex database further by scraping the height, weight, and base stats of the pokemon in our database.

# %%
# This code runs for about 15 minutes
for i, pokemon in pokemons.iterrows():
    # Scrape pokedex webpage of current pokemon
    response = get_webpage(pokemon['pokedex_url'], headers, sleep_time=5)
    soup = BeautifulSoup(response.content, 'html5lib')

    # Get height and weight
    pokemon['height'] = soup.find('th', string='Height').next_sibling.next_sibling.text
    pokemon['weight'] = soup.find('th', string='Weight').next_sibling.next_sibling.text

    # Parse the stats
    stats = {}
    for stat_elem in (soup.find('h2', string='Base stats').next_sibling
                          .next_sibling.select_one('table.vitals-table')
                          .find_all('th', limit=6)):
        stats[stat_elem.text] = int(stat_elem.next_sibling.next_sibling.text)
    pokemon['stats'] = stats

    # Write to output file
    with open('outputs/pokedex.jsonl', 'a') as f:
        f.write(pokemon.to_json() + '\n')
# Out:
# Page has been successfully fetched! https://pokemondb.net//pokedex/bulbasaur
# Page has been successfully fetched! https://pokemondb.net//pokedex/ivysaur
# Page has been successfully fetched! https://pokemondb.net//pokedex/venusaur
# Page has been successfully fetched! https://pokemondb.net//pokedex/charmander
# Page has been successfully fetched! https://pokemondb.net//pokedex/charmeleon
# Page has been successfully fetched! https://pokemondb.net//pokedex/charizard
# Page has been successfully fetched! https://pokemondb.net//pokedex/squirtle
# Page has been successfully fetched! https://pokemondb.net//pokedex/wartortle
# Page has been successfully fetched! https://pokemondb.net//pokedex/blastoise
# Page has been successfully fetched! https://pokemondb.net//pokedex/caterpie
# Page has been successfully fetched! https://pokemondb.net//pokedex/metapod
# Page has been successfully fetched! https://pokemondb.net//pokedex/butterfree
# Page has been successfully fetched! https://pokemondb.net//pokedex/weedle
# Page has been successfully fetched! https://pokemondb.net//pokedex/kakuna
# Page has been successfully fetched! https://pokemondb.net//pokedex/beedrill
# Page has been successfully fetched! https://pokemondb.net//pokedex/pidgey
# Page has been successfully fetched! https://pokemondb.net//pokedex/pidgeotto
# Page has been successfully fetched! https://pokemondb.net//pokedex/pidgeot
# Page has been successfully fetched! https://pokemondb.net//pokedex/rattata
# Page has been successfully fetched! https://pokemondb.net//pokedex/raticate
# Page has been successfully fetched! https://pokemondb.net//pokedex/spearow
# Page has been successfully fetched! https://pokemondb.net//pokedex/fearow
# Page has been successfully fetched! https://pokemondb.net//pokedex/ekans
# Page has been successfully fetched! https://pokemondb.net//pokedex/arbok
# Page has been successfully fetched! https://pokemondb.net//pokedex/pikachu
# Page has been successfully fetched! https://pokemondb.net//pokedex/raichu
# Page has been successfully fetched! https://pokemondb.net//pokedex/sandshrew
# Page has been successfully fetched! https://pokemondb.net//pokedex/sandslash
# Page has been successfully fetched! https://pokemondb.net//pokedex/nidoran-f
# Page has been successfully fetched! https://pokemondb.net//pokedex/nidorina
# Page has been successfully fetched! https://pokemondb.net//pokedex/nidoqueen
# Page has been successfully fetched! https://pokemondb.net//pokedex/nidoran-m
# Page has been successfully fetched! https://pokemondb.net//pokedex/nidorino
# Page has been successfully fetched! https://pokemondb.net//pokedex/nidoking
# Page has been successfully fetched! https://pokemondb.net//pokedex/clefairy
# Page has been successfully fetched! https://pokemondb.net//pokedex/clefable
# Page has been successfully fetched! https://pokemondb.net//pokedex/vulpix
# Page has been successfully fetched! https://pokemondb.net//pokedex/ninetales
# Page has been successfully fetched! https://pokemondb.net//pokedex/jigglypuff
# Page has been successfully fetched! https://pokemondb.net//pokedex/wigglytuff
# Page has been successfully fetched! https://pokemondb.net//pokedex/zubat
# Page has been successfully fetched! https://pokemondb.net//pokedex/golbat
# Page has been successfully fetched! https://pokemondb.net//pokedex/oddish
# Page has been successfully fetched! https://pokemondb.net//pokedex/gloom
# Page has been successfully fetched! https://pokemondb.net//pokedex/vileplume
# Page has been successfully fetched! https://pokemondb.net//pokedex/paras
# Page has been successfully fetched! https://pokemondb.net//pokedex/parasect
# Page has been successfully fetched! https://pokemondb.net//pokedex/venonat
# Page has been successfully fetched! https://pokemondb.net//pokedex/venomoth
# Page has been successfully fetched! https://pokemondb.net//pokedex/diglett
# Page has been successfully fetched! https://pokemondb.net//pokedex/dugtrio
# Page has been successfully fetched! https://pokemondb.net//pokedex/meowth
# Page has been successfully fetched! https://pokemondb.net//pokedex/persian
# Page has been successfully fetched! https://pokemondb.net//pokedex/psyduck
# Page has been successfully fetched! https://pokemondb.net//pokedex/golduck
# Page has been successfully fetched! https://pokemondb.net//pokedex/mankey
# Page has been successfully fetched! https://pokemondb.net//pokedex/primeape
# Page has been successfully fetched! https://pokemondb.net//pokedex/growlithe
# Page has been successfully fetched! https://pokemondb.net//pokedex/arcanine
# Page has been successfully fetched! https://pokemondb.net//pokedex/poliwag
# Page has been successfully fetched! https://pokemondb.net//pokedex/poliwhirl
# Page has been successfully fetched! https://pokemondb.net//pokedex/poliwrath
# Page has been successfully fetched! https://pokemondb.net//pokedex/abra
# Page has been successfully fetched! https://pokemondb.net//pokedex/kadabra
# Page has been successfully fetched! https://pokemondb.net//pokedex/alakazam
# Page has been successfully fetched! https://pokemondb.net//pokedex/machop
# Page has been successfully fetched! https://pokemondb.net//pokedex/machoke
# Page has been successfully fetched! https://pokemondb.net//pokedex/machamp
# Page has been successfully fetched! https://pokemondb.net//pokedex/bellsprout
# Page has been successfully fetched! https://pokemondb.net//pokedex/weepinbell
# Page has been successfully fetched! https://pokemondb.net//pokedex/victreebel
# Page has been successfully fetched! https://pokemondb.net//pokedex/tentacool
# Page has been successfully fetched! https://pokemondb.net//pokedex/tentacruel
# Page has been successfully fetched! https://pokemondb.net//pokedex/geodude
# Page has been successfully fetched! https://pokemondb.net//pokedex/graveler
# Page has been successfully fetched! https://pokemondb.net//pokedex/golem
# Page has been successfully fetched! https://pokemondb.net//pokedex/ponyta
# Page has been successfully fetched! https://pokemondb.net//pokedex/rapidash
# Page has been successfully fetched! https://pokemondb.net//pokedex/slowpoke
# Page has been successfully fetched! https://pokemondb.net//pokedex/slowbro
# Page has been successfully fetched! https://pokemondb.net//pokedex/magnemite
# Page has been successfully fetched! https://pokemondb.net//pokedex/magneton
# Page has been successfully fetched! https://pokemondb.net//pokedex/farfetchd
# Page has been successfully fetched! https://pokemondb.net//pokedex/doduo
# Page has been successfully fetched! https://pokemondb.net//pokedex/dodrio
# Page has been successfully fetched! https://pokemondb.net//pokedex/seel
# Page has been successfully fetched! https://pokemondb.net//pokedex/dewgong
# Page has been successfully fetched! https://pokemondb.net//pokedex/grimer
# Page has been successfully fetched! https://pokemondb.net//pokedex/muk
# Page has been successfully fetched! https://pokemondb.net//pokedex/shellder
# Page has been successfully fetched! https://pokemondb.net//pokedex/cloyster
# Page has been successfully fetched! https://pokemondb.net//pokedex/gastly
# Page has been successfully fetched! https://pokemondb.net//pokedex/haunter
# Page has been successfully fetched! https://pokemondb.net//pokedex/gengar
# Page has been successfully fetched! https://pokemondb.net//pokedex/onix
# Page has been successfully fetched! https://pokemondb.net//pokedex/drowzee
# Page has been successfully fetched! https://pokemondb.net//pokedex/hypno
# Page has been successfully fetched! https://pokemondb.net//pokedex/krabby
# Page has been successfully fetched! https://pokemondb.net//pokedex/kingler
# Page has been successfully fetched! https://pokemondb.net//pokedex/voltorb
# Page has been successfully fetched! https://pokemondb.net//pokedex/electrode
# Page has been successfully fetched! https://pokemondb.net//pokedex/exeggcute
# Page has been successfully fetched! https://pokemondb.net//pokedex/exeggutor
# Page has been successfully fetched! https://pokemondb.net//pokedex/cubone
# Page has been successfully fetched! https://pokemondb.net//pokedex/marowak
# Page has been successfully fetched! https://pokemondb.net//pokedex/hitmonlee
# Page has been successfully fetched! https://pokemondb.net//pokedex/hitmonchan
# Page has been successfully fetched! https://pokemondb.net//pokedex/lickitung
# Page has been successfully fetched! https://pokemondb.net//pokedex/koffing
# Page has been successfully fetched! https://pokemondb.net//pokedex/weezing
# Page has been successfully fetched! https://pokemondb.net//pokedex/rhyhorn
# Page has been successfully fetched! https://pokemondb.net//pokedex/rhydon
# Page has been successfully fetched! https://pokemondb.net//pokedex/chansey
# Page has been successfully fetched! https://pokemondb.net//pokedex/tangela
# Page has been successfully fetched! https://pokemondb.net//pokedex/kangaskhan
# Page has been successfully fetched! https://pokemondb.net//pokedex/horsea
# Page has been successfully fetched! https://pokemondb.net//pokedex/seadra
# Page has been successfully fetched! https://pokemondb.net//pokedex/goldeen
# Page has been successfully fetched! https://pokemondb.net//pokedex/seaking
# Page has been successfully fetched! https://pokemondb.net//pokedex/staryu
# Page has been successfully fetched! https://pokemondb.net//pokedex/starmie
# Page has been successfully fetched! https://pokemondb.net//pokedex/mr-mime
# Page has been successfully fetched! https://pokemondb.net//pokedex/scyther
# Page has been successfully fetched! https://pokemondb.net//pokedex/jynx
# Page has been successfully fetched! https://pokemondb.net//pokedex/electabuzz
# Page has been successfully fetched! https://pokemondb.net//pokedex/magmar
# Page has been successfully fetched! https://pokemondb.net//pokedex/pinsir
# Page has been successfully fetched! https://pokemondb.net//pokedex/tauros
# Page has been successfully fetched! https://pokemondb.net//pokedex/magikarp
# Page has been successfully fetched! https://pokemondb.net//pokedex/gyarados
# Page has been successfully fetched! https://pokemondb.net//pokedex/lapras
# Page has been successfully fetched! https://pokemondb.net//pokedex/ditto
# Page has been successfully fetched! https://pokemondb.net//pokedex/eevee
# Page has been successfully fetched! https://pokemondb.net//pokedex/vaporeon
# Page has been successfully fetched! https://pokemondb.net//pokedex/jolteon
# Page has been successfully fetched! https://pokemondb.net//pokedex/flareon
# Page has been successfully fetched! https://pokemondb.net//pokedex/porygon
# Page has been successfully fetched! https://pokemondb.net//pokedex/omanyte
# Page has been successfully fetched! https://pokemondb.net//pokedex/omastar
# Page has been successfully fetched! https://pokemondb.net//pokedex/kabuto
# Page has been successfully fetched! https://pokemondb.net//pokedex/kabutops
# Page has been successfully fetched! https://pokemondb.net//pokedex/aerodactyl
# Page has been successfully fetched! https://pokemondb.net//pokedex/snorlax
# Page has been successfully fetched! https://pokemondb.net//pokedex/articuno
# Page has been successfully fetched! https://pokemondb.net//pokedex/zapdos
# Page has been successfully fetched! https://pokemondb.net//pokedex/moltres
# Page has been successfully fetched! https://pokemondb.net//pokedex/dratini
# Page has been successfully fetched! https://pokemondb.net//pokedex/dragonair
# Page has been successfully fetched! https://pokemondb.net//pokedex/dragonite
# Page has been successfully fetched! https://pokemondb.net//pokedex/mewtwo
# Page has been successfully fetched! https://pokemondb.net//pokedex/mew

# %% [markdown]
# <img src="images/banner-down.png" style="width: 100%;">
